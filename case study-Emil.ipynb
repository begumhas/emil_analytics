# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Begüm Has\Documents\OnlineRetail.csv")

# %%
#df['CustomerID'] = df['CustomerID'].astype(int)
#df[df.CustomerID.notnull()]
#df[df['Quantity'] < 0]
#df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

#data cleaning

#df['Quantity'] = df['Quantity'].abs()
#df['UnitPrice'] = df['UnitPrice'].abs()
#df['CustomerID'] = df['CustomerID'].astype(str).str[:-2]
#df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']).dt.date
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice CustomerID         Country  UnitAmount
# ...

# %%
#calculate unit amount
df['UnitAmount'] = df['Quantity'] * df['UnitPrice']
df
#df_unit = df.groupby(['InvoiceNo','StockCode','Description','InvoiceDate','CustomerID','Country','Quantity'])[['UnitAmount']].agg('sum')
#df_unit.head(7)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice CustomerID         Country  UnitAmount
# ...

# %%
#df_invoice = df.groupby(['InvoiceNo','InvoiceDate','CustomerID','Country'])[['UnitAmount'],['Quantity']].agg('sum')
df_invoice = df.groupby(['InvoiceNo','InvoiceDate','CustomerID','Country']).agg({'UnitAmount':'sum','Quantity':'sum'})
df_invoice = df_invoice.rename(columns={'UnitAmount': 'TotalUnitAmount','Quantity': 'TotalUnitQuantity'})
df_invoice#.head(7)
# Out:
#                                                          TotalUnitAmount  \
# InvoiceNo InvoiceDate         CustomerID Country
# 536365    2010-12-01 08:26:00 17850      United Kingdom           139.12
# 536366    2010-12-01 08:28:00 17850      United Kingdom            22.20
# 536367    2010-12-01 08:34:00 13047      United Kingdom           278.73
# 536368    2010-12-01 08:34:00 13047      United Kingdom            70.05
# 536369    2010-12-01 08:35:00 13047      United Kingdom            17.85
# ...                                                                  ...
# C581484   2011-12-09 09:27:00 16446      United Kingdom        168469.60
# C581490   2011-12-09 09:57:00 14397      United Kingdom            32.53
# C581499   2011-12-09 10:28:00 15498      United Kingdom           224.69
# C581568   2011-12-09 11:57:00 15311      United Kingdom            54.75
# C581569   2011-12-09 11:58:00 17315      United Kingdom             7.50
#
# ...

# %%
#import dataframe to csv file
df.to_csv(r'C:\Users\Begüm Has\Documents\OnlineRetail_cleaned.csv', index = False)
